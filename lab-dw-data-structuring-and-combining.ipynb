# %% [markdown]
# # Lab | Data Structuring and Combining Data

# %% [markdown]
# ## Challenge 1: Combining & Cleaning Data
#
# In this challenge, we will be working with the customer data from an insurance company, as we did in the two previous labs. The data can be found here:
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv
#
# But this time, we got new data, which can be found in the following 2 CSV files located at the links below.
#
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv
#
# Note that you'll need to clean and format the new data.
#
# Observation:
# - One option is to first combine the three datasets and then apply the cleaning function to the new combined dataset
# - Another option would be to read the clean file you saved in the previous lab, and just clean the two new files and concatenate the three clean datasets

# %%
import pandas as pd

old_data = pd.read_csv(r"C:\Users\Atefah\Desktop\IRONHACK\UNIT 4\lab-dw-data-cleaning-and-formatting\cleaned_dataset.csv")

# %%
old_data
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington      F                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 1067  VJ51327  California      F  High School or Below
# 1068  GS98873     Arizona      F              Bachelor
# 1069  CW49887  California      F                Master
# 1070  MY31220  California      F               College
# 1071      NaN         NaN      F                   NaN
#
#       customer_lifetime_value   income  monthly_premium_auto  \
# 0                         NaN      0.0                1000.0
# 1                   697953.59      0.0                  94.0
# 2                  1288743.17  48767.0                 108.0
# ...

# %%
old_data.dtypes
# Out:
# customer                      object
# state                         object
# gender                        object
# education                     object
# customer_lifetime_value      float64
# income                       float64
# monthly_premium_auto         float64
# number_of_open_complaints    float64
# policy_type                   object
# vehicle_class                 object
# total_claim_amount           float64
# dtype: object

# %%
old_data.value_counts()
# Out:
# customer  state       gender  education             customer_lifetime_value  income   monthly_premium_auto  number_of_open_complaints  policy_type     vehicle_class  total_claim_amount
# AA71604   Arizona     F       Master                1198659.21               87560.0  98.0                  1.0                        Personal Auto   Two-Door Car   470.400000            1
# RK96223   California  M       College               1294189.19               52369.0  110.0                 1.0                        Personal Auto   SUV            528.000000            1
# RB69909   Nevada      F       High School or Below  798343.17                36014.0  69.0                  3.0                        Special Auto    Four-Door Car  173.956072            1
# RC62865   Oregon      M       College               351738.58                51814.0  92.0                  0.0                        Personal Auto   Four-Door Car  56.300724             1
# ...

# %%
data1 = pd.read_csv(r"https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv")

# %%
data1
# Out:
#     Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# ...

# %%
data1.rename(columns={'Customer': 'customer', 'ST':'state', 'GENDER': 'gender', 'Education': 'education', 'Customer Lifetime Value': 'customer_lifetime_value' ,
       'Income': 'income', 'Monthly Premium Auto': 'monthly_premium_auto', 'Number of Open Complaints': 'number_of_open_complaints',
       'Policy Type': 'policy_type' , 'Vehicle Class': 'vehicle_class', 'Total Claim Amount': 'total_claim_amount'}, inplace=True)

# %%
data1
# Out:
#     customer       state gender education customer_lifetime_value  income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      monthly_premium_auto number_of_open_complaints  total_claim_amount  \
# ...

# %%
data1 = data1.loc[:, ~data1.columns.duplicated()]

# %%
data1
# Out:
#     customer       state gender education customer_lifetime_value  income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      monthly_premium_auto number_of_open_complaints  total_claim_amount  \
# ...

# %%
data1.dtypes
# Out:
# customer                      object
# state                         object
# gender                        object
# education                     object
# customer_lifetime_value       object
# income                         int64
# monthly_premium_auto           int64
# number_of_open_complaints     object
# total_claim_amount           float64
# policy_type                   object
# vehicle_class                 object
# dtype: object

# %%
print(data1['number_of_open_complaints'].unique())
# Out:
# ['1/0/00' '1/1/00' '1/3/00' '1/5/00' '1/2/00' '1/4/00']

# %%
data1['number_of_open_complaints'] = data1['number_of_open_complaints'].astype(str)

# Since the integers are already in string format, split by '/'
data1['number_of_open_complaints'] = data1['number_of_open_complaints'].str.split('/').str[1]

# Convert back to integer after extracting the middle value
data1['number_of_open_complaints'] = pd.to_numeric(data1['number_of_open_complaints'], errors='coerce')

# Verify the result
data1['number_of_open_complaints'].value_counts()
# Out:
# number_of_open_complaints
# 0    796
# 1    109
# 2     43
# 3     26
# 4     16
# 5      6
# Name: count, dtype: int64

# %%
data1['customer_lifetime_value'] = data1['customer_lifetime_value'].replace('%', '', regex=True)

# %%
data1 = data1.astype({'customer_lifetime_value': 'float64'})

# %%
data1 = data1.astype({
    'income': 'float64',
    'monthly_premium_auto': 'float64',
    'number_of_open_complaints': 'float64',
    'policy_type': 'object',
    'total_claim_amount': 'float64'
})

# %%
data1.dtypes
# Out:
# customer                      object
# state                         object
# gender                        object
# education                     object
# customer_lifetime_value      float64
# income                       float64
# monthly_premium_auto         float64
# number_of_open_complaints    float64
# total_claim_amount           float64
# policy_type                   object
# vehicle_class                 object
# dtype: object

# %%
data1 = data1[[col for col in data1.columns if col != 'total_claim_amount'] + ['total_claim_amount']]

# %%
data1
# Out:
#     customer       state gender education  customer_lifetime_value   income  \
# 0    GS98873     Arizona      F  Bachelor                323912.47  16061.0
# 1    CW49887  California      F    Master                462680.11  79487.0
# 2    MY31220  California      F   College                899704.02  54230.0
# 3    UH35128      Oregon      F   College               2580706.30  71210.0
# 4    WH52799     Arizona      F   College                380812.21  94903.0
# ..       ...         ...    ...       ...                      ...      ...
# 991  HV85198     Arizona      M    Master                847141.75  63513.0
# 992  BS91566     Arizona      F   College                543121.91  58161.0
# 993  IL40123      Nevada      F   College                568964.41  83640.0
# 994  MY32149  California      F    Master                368672.38      0.0
# 995  SA91515  California      M  Bachelor                399258.39      0.0
#
# ...

# %%
number_of_open_complaints
# Out:
# Series([], Name: count, dtype: int64)

# %%
data1['vehicle_class'].value_counts()
# Out:
# vehicle_class
# Four-Door Car    519
# Two-Door Car     211
# SUV              174
# Luxury            92
# Name: count, dtype: int64

# %%
data1['vehicle_class'] = data1['vehicle_class'].replace({"Four-Door Car": "Four-Door Car", "Two-Door Car": "Two-Door Car", 
"SUV": "SUV", "Sports Car": "Luxury", "Luxury SUV": "Luxury", "Luxury Car":  "Luxury"})

data1['vehicle_class'].value_counts()
# Out:
# vehicle_class
# Four-Door Car    519
# Two-Door Car     211
# SUV              174
# Luxury            92
# Name: count, dtype: int64

# %%
education_mapping = {"Bachelor": "Bachelor", "Bachelors": "Bachelor", "College": "College", "High School or Below": "High School or Below", "Master": "Master", "Doctor": "Doctor"}
data1['education'] = data1['education'].map(education_mapping)
print(data1['education'].unique())
# Out:
# ['Bachelor' 'Master' 'College' 'Doctor' 'High School or Below']

# %%
data1['education'].value_counts()
# Out:
# education
# College                 311
# High School or Below    290
# Bachelor                260
# Master                   86
# Doctor                   49
# Name: count, dtype: int64

# %%
data1['state'] = data1['state'].replace({"AZ": "Arizona", 
                                   "Cali": "California", 
                                   "WA": "Washington", 
                                   "Oregon": "Oregon", 
                                   "Nevada": "Nevada", 
                                   "Washington": "Washington", 
                                   "California": "California", 
                                   "Arizona": "Arizona"})
print(data1['state'].unique())
# Out:
# ['Arizona' 'California' 'Oregon' 'Nevada' 'Washington']

# %%
data1.to_csv('cleaned_data1.csv', index=False)

print("All changes to data1 have been saved to 'cleaned_data1.csv'")
# Out:
# All changes to data1 have been saved to 'cleaned_data1.csv'

# %%
data2 = pd.read_csv(r"https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv")

# %%
data2
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %%
data2.rename(columns={'Customer': 'customer', 'ST':'state', 'GENDER': 'gender', 'Education': 'education', 'Customer Lifetime Value': 'customer_lifetime_value' ,
       'Income': 'income', 'Monthly Premium Auto': 'monthly_premium_auto', 'Number of Open Complaints': 'number_of_open_complaints',
       'Policy Type': 'policy_type' , 'Vehicle Class': 'vehicle_class', 'Total Claim Amount': 'total_claim_amount'}, inplace=True)

# %%
data2
# Out:
#      customer       State  customer_lifetime_value             education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  income  monthly_premium_auto  number_of_open_complaints  \
# ...

# %%
data2.dtypes
# Out:
# customer                      object
# State                         object
# customer_lifetime_value      float64
# education                     object
# Gender                        object
# income                         int64
# monthly_premium_auto           int64
# number_of_open_complaints      int64
# policy_type                   object
# total_claim_amount           float64
# vehicle_class                 object
# dtype: object

# %%
data2 = data2.astype({
    'income': 'float64',
    'monthly_premium_auto': 'float64',
    'number_of_open_complaints': 'float64'
})

# %%
data2.rename(columns={'State': 'state', 'Gender': 'gender'}, inplace=True)
data2 = data2[data1.columns]

# %%
data2 = data2[[col for col in data1.columns if col != 'total_claim_amount'] + ['total_claim_amount']]

# %%
data2
# Out:
#      customer       state gender             education  \
# 0     SA25987  Washington      M  High School or Below
# 1     TB86706     Arizona      M                Master
# 2     ZL73902      Nevada      F              Bachelor
# 3     KX23516  California      F  High School or Below
# 4     FN77294  California      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#       customer_lifetime_value   income  monthly_premium_auto  \
# 0                 3479.137523      0.0                 104.0
# 1                 2502.637401      0.0                  66.0
# 2                 3265.156348  25820.0                  82.0
# ...

# %%
data2['customer_lifetime_value'] = data2['customer_lifetime_value'].replace('%', '', regex=True)
data2 = data2.astype({'customer_lifetime_value': 'float64'})
data2 = data2.astype({
    'income': 'float64',
    'monthly_premium_auto': 'float64',
    'number_of_open_complaints': 'float64',
    'policy_type': 'object',
    'total_claim_amount': 'float64'
})
data2 = data2[[col for col in data1.columns if col != 'total_claim_amount'] + ['total_claim_amount']]
data2['vehicle_class'] = data2['vehicle_class'].replace({"Four-Door Car": "Four-Door Car", "Two-Door Car": "Two-Door Car", 
"SUV": "SUV", "Sports Car": "Luxury", "Luxury SUV": "Luxury", "Luxury Car":  "Luxury"})

data2['vehicle_class'].value_counts()
education_mapping = {"Bachelor": "Bachelor", "Bachelors": "Bachelor", "College": "College", "High School or Below": "High School or Below", "Master": "Master", "Doctor": "Doctor"}
data2['education'] = data2['education'].map(education_mapping)
print(data2['education'].unique())
data2['state'] = data2['state'].replace({"AZ": "Arizona", 
                                   "Cali": "California", 
                                   "WA": "Washington", 
                                   "Oregon": "Oregon", 
                                   "Nevada": "Nevada", 
                                   "Washington": "Washington", 
                                   "California": "California", 
                                   "Arizona": "Arizona"})
print(data2['state'].unique())
# Out:
# ['High School or Below' 'Master' 'Bachelor' 'College' 'Doctor']
# ['Washington' 'Arizona' 'Nevada' 'California' 'Oregon']

# %%
data2
# Out:
#      customer       state gender             education  \
# 0     SA25987  Washington      M  High School or Below
# 1     TB86706     Arizona      M                Master
# 2     ZL73902      Nevada      F              Bachelor
# 3     KX23516  California      F  High School or Below
# 4     FN77294  California      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#       customer_lifetime_value   income  monthly_premium_auto  \
# 0                 3479.137523      0.0                 104.0
# 1                 2502.637401      0.0                  66.0
# 2                 3265.156348  25820.0                  82.0
# ...

# %%
data1.dtypes
# Out:
# customer                      object
# state                         object
# gender                        object
# education                     object
# customer_lifetime_value      float64
# income                       float64
# monthly_premium_auto         float64
# number_of_open_complaints    float64
# policy_type                   object
# vehicle_class                 object
# total_claim_amount           float64
# dtype: object

# %%
data2
# Out:
#      customer       state gender             education  \
# 0     SA25987  Washington      M  High School or Below
# 1     TB86706     Arizona      M                Master
# 2     ZL73902      Nevada      F              Bachelor
# 3     KX23516  California      F  High School or Below
# 4     FN77294  California      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#       customer_lifetime_value   income  monthly_premium_auto  \
# 0                 3479.137523      0.0                 104.0
# 1                 2502.637401      0.0                  66.0
# 2                 3265.156348  25820.0                  82.0
# ...

# %%
data2.to_csv('cleaned_data2.csv', index=False)

print("All changes to data2 have been saved to 'cleaned_data2.csv'")
# Out:
# All changes to data2 have been saved to 'cleaned_data2.csv'

# %%
# Combine the datasets
combined_data = pd.concat([old_data, data1, data2], ignore_index=True)

# Save the combined data to a CSV file
combined_data.to_csv('combined_data.csv', index=False)

print("Combined data has been saved to 'combined_data.csv'")

# %%
combined_data = pd.concat([old_data, data1, data2], ignore_index=True)
print(combined_data)
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington      F                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 9133  LA72316  California      M              Bachelor
# 9134  PK87824  California      F               College
# 9135  TD14365  California      M              Bachelor
# 9136  UP19263  California      M               College
# 9137  Y167826  California      M               College
#
#       customer_lifetime_value   income  monthly_premium_auto  \
# 0                         NaN      0.0                1000.0
# 1                6.979536e+05      0.0                  94.0
# 2                1.288743e+06  48767.0                 108.0
# ...

# %%
combined_data.to_csv('combined_data.csv', index=False)

print("Combined data has been saved to 'combined_data.csv'")
# Out:
# Combined data has been saved to 'combined_data.csv'

# %%
combined_data
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington      F                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 9133  LA72316  California      M              Bachelor
# 9134  PK87824  California      F               College
# 9135  TD14365  California      M              Bachelor
# 9136  UP19263  California      M               College
# 9137  Y167826  California      M               College
#
#       customer_lifetime_value   income  monthly_premium_auto  \
# 0                         NaN      0.0                1000.0
# 1                6.979536e+05      0.0                  94.0
# 2                1.288743e+06  48767.0                 108.0
# ...

# %% [markdown]
# # Challenge 2: Structuring Data

# %% [markdown]
# In this challenge, we will continue to work with customer data from an insurance company, but we will use a dataset with more columns, called marketing_customer_analysis.csv, which can be found at the following link:
#
# https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv
#
# This dataset contains information such as customer demographics, policy details, vehicle information, and the customer's response to the last marketing campaign. Our goal is to explore and analyze this data by performing data cleaning, formatting, and structuring.

# %%
# Your code goes here
data4 = pd.read_csv(r"https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv")

# %%
data4
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877  California              6857.519928       No
#
#        coverage education effective_to_date employmentstatus gender  ...  \
# ...

# %% [markdown]
# 1. You work at the marketing department and you want to know which sales channel brought the most sales in terms of total revenue. Using pivot, create a summary table showing the total revenue for each sales channel (branch, call center, web, and mail).
# Round the total revenue to 2 decimal points.  Analyze the resulting table to draw insights.

# %%
# Create a pivot table to calculate total revenue for each sales channel
sales_channel_revenue = data4.pivot_table(
    index='sales_channel',
    values='total_claim_amount',
    aggfunc='sum'
).round(2)

# Sort the table by total revenue in descending order
sales_channel_revenue = sales_channel_revenue.sort_values(by='total_claim_amount', ascending=False)

print(sales_channel_revenue)
# Out:
#                total_claim_amount
# sales_channel
# Agent                  1810226.82
# Branch                 1301204.00
# Call Center             926600.82
# Web                     706600.04

# %% [markdown]
# 2. Create a pivot table that shows the average customer lifetime value per gender and education level. Analyze the resulting table to draw insights.

# %%
# Create a pivot table to calculate the average customer lifetime value per gender and education level
avg_clv_pivot = data4.pivot_table(
    index='gender',
    columns='education',
    values='customer_lifetime_value',
    aggfunc='mean'
).round(2)

# Display the pivot table
print(avg_clv_pivot)
# Out:
# education  Bachelor  College   Doctor  High School or Below   Master
# gender
# F           7874.27  7748.82  7328.51               8675.22  8157.05
# M           7703.60  8052.46  7415.33               8149.69  8168.83

# %% [markdown]
# ## Bonus
#
# You work at the customer service department and you want to know which months had the highest number of complaints by policy type category. Create a summary table showing the number of complaints by policy type and month.
# Show it in a long format table.

# %% [markdown]
# *In data analysis, a long format table is a way of structuring data in which each observation or measurement is stored in a separate row of the table. The key characteristic of a long format table is that each column represents a single variable, and each row represents a single observation of that variable.*
#
# *More information about long and wide format tables here: https://www.statology.org/long-vs-wide-data/*

# %%
# Your code goes here
